# %% [markdown]
# # S12 — ZeRO stages on 32 virtual ranks

# %%
from pathlib import Path
script = Path('S12/run_demo.py') if Path('S12/run_demo.py').exists() else Path('run_demo.py')
get_ipython().run_line_magic('run', str(script))

# %% [markdown]
# See `S12/artifacts/evidence.json`, `run.log`, and `zero_comparison.png`.
