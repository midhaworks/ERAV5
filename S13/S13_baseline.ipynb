# %% [markdown]
# # S13 baseline — 20M model, 50M tokens

# %%
from pathlib import Path
script=Path('S13/train.py') if Path('S13/train.py').exists() else Path('train.py')
get_ipython().run_line_magic('run', str(script)+' --variant baseline --batch-size 8 --corpus S13/data.txt')
