# %% [markdown]
# # S13 Euler-reversible maximum batch

# %%
from pathlib import Path
script=Path('S13/train.py') if Path('S13/train.py').exists() else Path('train.py')
get_ipython().run_line_magic('run', str(script)+' --variant euler --auto-max-batch --corpus S13/data.txt')
