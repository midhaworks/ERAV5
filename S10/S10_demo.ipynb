# %% [markdown]
# # S10 — Correct and observable training
#
# Run the complete local PyTorch harness below.

# %%
# %run S10/run_demo.py

# %% [markdown]
# The generated `artifacts/` directory contains the complete log, JSON evidence, gradient trace, and accumulation plot.
